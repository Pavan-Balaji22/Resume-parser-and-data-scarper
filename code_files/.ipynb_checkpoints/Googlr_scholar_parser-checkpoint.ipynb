# %%
import pandas as pd

# %%
n = pd.read_csv("Name.csv")

# %%
from scholarly import scholarly as sc

# %%
google_dict = {}
missed_names = []
for i,x in enumerate(n.iloc[:,0]):
    temp = sc.search_author(x)
    try:
        google_dict[x] = sc.fill(next(temp))
    except:
        missed_names.append(x)

# %%
def process_author_gs(author_json):
    '''
        Function to process authour information from author profiles from google
        scholar.
        
        Parameters
        ----------
        author_json - author information stored in json format
        
        Returns
        -------
        author_info - author information in form of dictionary
        
    '''
    temp = {}
    
    temp["university"] = author_json["affiliation"]
    temp["total_citation"] = author_json["citedby"]
    temp["hindex"] = author_json["hindex"]
    temp["Years active"] = list(author_json["cites_per_year"].keys())[-1] - list(a["cites_per_year"].keys())[0]
    temp["No_of_publication"] = len(author_json["publications"])
    
    return temp

# %%
ret_data = {}

# %%
for i in google_dict.keys():
    ret_data[i] = process_author_gs(google_dict[i])

# %%
a=google_dict["Alison Flynn"]

# %%
process_author_gs(a)
# Out:
# {'university': 'University of Ottawa',
#  'total_citation': 1730,
#  'hindex': 22,
#  'Years active': 15,
#  'No_of_publication': 74}

# %%
ret_data
# Out:
# {'DANIEL J. BENNETT': {'university': 'Medical Student, UCSF',
#   'total_citation': 37,
#   'hindex': 3,
#   'Years active': 15,
#   'No_of_publication': 18},
#  'Easton R. White': {'university': 'University of New Hampshire',
#   'total_citation': 709,
#   'hindex': 13,
#   'Years active': 15,
#   'No_of_publication': 40},
#  'Eric Stabb': {'university': 'University of Illinois at Chicago',
#   'total_citation': 5789,
#   'hindex': 37,
#   'Years active': 15,
#   'No_of_publication': 82},
#  'JENNIFER M. BHATNAGAR': {'university': 'Assistant Professor of Microbial Ecology, Boston University',
#   'total_citation': 3764,
#   'hindex': 25,
#   'Years active': 15,
#   'No_of_publication': 87},
#  'John J. Ewel': {'university': 'Professor of Biology (emeritus), University of Florida',
#   'total_citation': 23273,
#   'hindex': 52,
#   'Years active': 15,
#   'No_of_publication': 152},
#  'JOHN SAKULICH': {'university': 'Regis University',
#   'total_citation': 396,
#   'hindex': 8,
#   'Years active': 15,
#   'No_of_publication': 15},
#  'LAURA J. OLSEN': {'university': 'Professor, University of Colorado, Boulder',
#   'total_citation': 350,
#   'hindex': 6,
#   'Years active': 15,
#   'No_of_publication': 25},
#  'Michael E. Burns': {'university': 'Jacksonville State University',
#   'total_citation': 934,
#   'hindex': 19,
#   'Years active': 15,
#   'No_of_publication': 84},
#  'Michael I. Coates': {'university': 'Professor, Organismal Biology & Anatomy, University of Chicago',
#   'total_citation': 6416,
#   'hindex': 42,
#   'Years active': 15,
#   'No_of_publication': 135},
#  'Stephen Wagner': {'university': 'Medical University of Vienna',
#   'total_citation': 17826,
#   'hindex': 43,
#   'Years active': 15,
#   'No_of_publication': 208},
#  'WILLIAM I. LUTTERSCHMIDT': {'university': 'Sam Houston State University',
#   'total_citation': 2217,
#   'hindex': 18,
#   'Years active': 15,
#   'No_of_publication': 88},
#  'William R. McCleary': {'university': 'Associate Professor of Microbiology, Brigham Young University',
#   'total_citation': 2900,
#   'hindex': 20,
#   'Years active': 15,
#   'No_of_publication': 27},
#  'ALEXANDROS MAKRIYANNIS': {'university': 'Northeastern University',
#   'total_citation': 32700,
#   'hindex': 93,
#   'Years active': 15,
#   'No_of_publication': 822},
#  'Alison Flynn': {'university': 'University of Ottawa',
#   'total_citation': 1730,
#   'hindex': 22,
#   'Years active': 15,
#   'No_of_publication': 74},
#  'ANDREI TOKMAKOFF': {'university': 'University of Chicago',
#   'total_citation': 17550,
#   'hindex': 73,
#   'Years active': 15,
#   'No_of_publication': 274},
#  'Arthur Bragg': {'university': 'Department of Chemistry, Johns Hopkins University',
#   'total_citation': 3184,
#   'hindex': 27,
#   'Years active': 15,
#   'No_of_publication': 93},
#  'Bing Xu': {'university': 'Facebook',
#   'total_citation': 50589,
#   'hindex': 12,
#   'Years active': 15,
#   'No_of_publication': 14},
#  'C. Dale Keefe': {'university': 'Professor of Chemistry, Acadia University',
#   'total_citation': 1237,
#   'hindex': 22,
#   'Years active': 15,
#   'No_of_publication': 59},
#  'Cathleen Crudden': {'university': "Queen's University",
#   'total_citation': 9225,
#   'hindex': 53,
#   'Years active': 15,
#   'No_of_publication': 213},
#  'Cecilia I. Zurita Lopez': {'university': 'Assistant Professor of Biochemistry, California State University, Los Angeles',
#   'total_citation': 1215,
#   'hindex': 14,
#   'Years active': 15,
#   'No_of_publication': 25},
#  'Chng Shu Sin': {'university': 'National University of Singapore',
#   'total_citation': 2192,
#   'hindex': 21,
#   'Years active': 15,
#   'No_of_publication': 33},
#  'Curtis Berlinguette': {'university': 'The University of British Columbia',
#   'total_citation': 12112,
#   'hindex': 57,
#   'Years active': 15,
#   'No_of_publication': 240},
#  'Deryn Fogg': {'university': 'Professor of Chemistry, University of Ottawa',
#   'total_citation': 6366,
#   'hindex': 43,
#   'Years active': 15,
#   'No_of_publication': 141},
#  'FRASER F. FLEMING': {'university': 'Professor of Chemistry, Drexel University',
#   'total_citation': 4187,
#   'hindex': 27,
#   'Years active': 15,
#   'No_of_publication': 150},
#  'Gregory J. Smith': {'university': 'University of North Carolina',
#   'total_citation': 1265,
#   'hindex': 16,
#   'Years active': 15,
#   'No_of_publication': 58},
#  'Gregory K. Friestad': {'university': 'University of Iowa',
#   'total_citation': 2946,
#   'hindex': 29,
#   'Years active': 15,
#   'No_of_publication': 91},
#  'Gregory R. Bowman': {'university': 'Associate Professor, Washington University in St Louis',
#   'total_citation': 8096,
#   'hindex': 43,
#   'Years active': 15,
#   'No_of_publication': 83},
#  'J. Martin Scholtz': {'university': 'University of Iowa',
#   'total_citation': 15942,
#   'hindex': 53,
#   'Years active': 15,
#   'No_of_publication': 121},
#  'Jason Gilmore': {'university': 'Professor of Chemistry & Schaap Research Fellow, Hope College, Holland, MI USA',
#   'total_citation': 395,
#   'hindex': 12,
#   'Years active': 14,
#   'No_of_publication': 49},
#  'Jennifer D. Adams': {'university': 'Associate Professor and Canada Research Chair, University of Calgary',
#   'total_citation': 879,
#   'hindex': 16,
#   'Years active': 15,
#   'No_of_publication': 83},
#  'Jimmy Blair': {'university': 'Boys Town National Research Hospital',
#   'total_citation': 49243,
#   'hindex': 106,
#   'Years active': 15,
#   'No_of_publication': 380},
#  'Julian Chan': {'university': 'Scientist III (P.I.), Institute Sustainability for Chemicals, Energy & Environment, A*STAR',
#   'total_citation': 2349,
#   'hindex': 28,
#   'Years active': 15,
#   'No_of_publication': 56},
#  'Katharina M. Fromm': {'university': 'Professor of Chemistry, University of Fribourg',
#   'total_citation': 10520,
#   'hindex': 43,
#   'Years active': 15,
#   'No_of_publication': 320},
#  'Malika Jeffries-EL': {'university': 'Professor of Chemistry and Materials Science and Engineering, Boston University',
#   'total_citation': 3766,
#   'hindex': 27,
#   'Years active': 15,
#   'No_of_publication': 92},
#  'Matt F. Simcik': {'university': 'University of Minnesota',
#   'total_citation': 4646,
#   'hindex': 24,
#   'Years active': 15,
#   'No_of_publication': 42},
#  'Matthew L. Miller': {'university': 'Assistant Professor, University of Michigan',
#   'total_citation': 1557,
#   'hindex': 16,
#   'Years active': 15,
#   'No_of_publication': 47},
#  'Michael A. Brook': {'university': "Head of Cancer Genetics, Canada's Michael Smith Genome Sciences Centre, BC Cancer Agency Professor",
#   'total_citation': 20387,
#   'hindex': 59,
#   'Years active': 15,
#   'No_of_publication': 213},
#  'Michael Organ': {'university': 'Professor of Chemistry',
#   'total_citation': 13397,
#   'hindex': 55,
#   'Years active': 15,
#   'No_of_publication': 253},
#  'Nicolai Lehnert': {'university': 'Professor of Chemistry, University of Michigan',
#   'total_citation': 8825,
#   'hindex': 50,
#   'Years active': 15,
#   'No_of_publication': 251},
#  'P. Shiv Halasyamani': {'university': 'University of Houston',
#   'total_citation': 14639,
#   'hindex': 68,
#   'Years active': 15,
#   'No_of_publication': 306},
#  'Paul Mayer': {'university': 'US Environmental Protection Agency',
#   'total_citation': 4750,
#   'hindex': 34,
#   'Years active': 15,
#   'No_of_publication': 144},
#  'Phillip Sharp': {'university': 'Merck',
#   'total_citation': 3720,
#   'hindex': 14,
#   'Years active': 15,
#   'No_of_publication': 24},
#  'Piotr Piecuch': {'university': 'University Distinguished Professor and MSU Foundation Professor, Michigan State University',
#   'total_citation': 15000,
#   'hindex': 67,
#   'Years active': 15,
#   'No_of_publication': 240},
#  'Robert Campbell': {'university': 'Professor of Thoracic Oncology, University of Cambridge; Royal Papworth Hospital',
#   'total_citation': 23527,
#   'hindex': 61,
#   'Years active': 15,
#   'No_of_publication': 245},
#  'ROBERT H. MORRIS': {'university': 'Professor of Chemistry',
#   'total_citation': 19759,
#   'hindex': 70,
#   'Years active': 15,
#   'No_of_publication': 345},
#  'Roman Krems': {'university': 'University of British Columbia',
#   'total_citation': 8025,
#   'hindex': 43,
#   'Years active': 15,
#   'No_of_publication': 190},
#  'Scott A. Snyder': {'university': 'Professor of chemistry',
#   'total_citation': 10170,
#   'hindex': 46,
#   'Years active': 15,
#   'No_of_publication': 176},
#  'Sherri A. Mason': {'university': 'Directory of Sustainability, Penn State Erie, The Behrend College',
#   'total_citation': 6369,
#   'hindex': 20,
#   'Years active': 15,
#   'No_of_publication': 41},
#  'Stefano Cesco': {'university': 'Professor of Agricultural Chemistry, Free University of Bolzano-Bozen',
#   'total_citation': 7456,
#   'hindex': 48,
#   'Years active': 15,
#   'No_of_publication': 413},
#  'Stephen Newman': {'university': 'University of Bath, UK',
#   'total_citation': 13997,
#   'hindex': 46,
#   'Years active': 15,
#   'No_of_publication': 336},
#  'Steve Scheiner': {'university': 'Utah State Univ',
#   'total_citation': 26568,
#   'hindex': 83,
#   'Years active': 15,
#   'No_of_publication': 559},
#  'Steven Holdcroft': {'university': 'Simon Fraser University, Department of Chemistry',
#   'total_citation': 19918,
#   'hindex': 77,
#   'Years active': 15,
#   'No_of_publication': 408},
#  'Sudeep Bhattacharyay': {'university': 'Associate Professor, Department of Chemistry and Biochemistry, University of Wisconsin',
#   'total_citation': 1004,
#   'hindex': 17,
#   'Years active': 15,
#   'No_of_publication': 53},
#  'Tara Kahan': {'university': 'University of Saskatchewan',
#   'total_citation': 1893,
#   'hindex': 24,
#   'Years active': 15,
#   'No_of_publication': 97},
#  'Thomas Baumgartner': {'university': 'University of Bern, Switzerland',
#   'total_citation': 8583,
#   'hindex': 26,
#   'Years active': 15,
#   'No_of_publication': 42},
#  'Thomas Vogt': {'university': 'University of South Carolina',
#   'total_citation': 19626,
#   'hindex': 64,
#   'Years active': 15,
#   'No_of_publication': 501},
#  'TYLER MELDRUM': {'university': 'Department of Chemistry, William & Mary',
#   'total_citation': 454,
#   'hindex': 12,
#   'Years active': 15,
#   'No_of_publication': 28},
#  'Véronique GOUVERNEUR': {'university': 'University of Oxford',
#   'total_citation': 18909,
#   'hindex': 64,
#   'Years active': 15,
#   'No_of_publication': 355},
#  'YUAN LIU': {'university': 'Hunan University, China',
#   'total_citation': 15492,
#   'hindex': 45,
#   'Years active': 15,
#   'No_of_publication': 107},
#  'Jacqueline E. Rice': {'university': 'University of Lethbridge',
#   'total_citation': 948,
#   'hindex': 17,
#   'Years active': 15,
#   'No_of_publication': 71},
#  'S. Raghavan': {'university': 'University of Maryland, Professor of Chemical and Biomolecular Engineering',
#   'total_citation': 15623,
#   'hindex': 71,
#   'Years active': 15,
#   'No_of_publication': 202},
#  'Amalin Prince': {'university': 'Associate Professor',
#   'total_citation': 242,
#   'hindex': 9,
#   'Years active': 15,
#   'No_of_publication': 48},
#  'Arindam Sarkar': {'university': 'Indian Institute of Technology Bombay, The University of Texas at Austin, Lawrence Berkeley National',
#   'total_citation': 1743,
#   'hindex': 15,
#   'Years active': 15,
#   'No_of_publication': 41},
#  'Jeanne Marie VanBriesen': {'university': 'Department of Civil and Environmental Engineering at Carnegie Mellon University',
#   'total_citation': 7269,
#   'hindex': 35,
#   'Years active': 15,
#   'No_of_publication': 163},
#  'Manjusri Misra': {'university': 'Professor and Tier 1 Canada Research Chair in Sustainable Biocomposites, University of Guelph',
#   'total_citation': 37199,
#   'hindex': 88,
#   'Years active': 15,
#   'No_of_publication': 818},
#  'Ben Webster': {'university': 'Associate Professor of Mathematics, University of Waterloo and Associate Faculty, Perimeter',
#   'total_citation': 1690,
#   'hindex': 23,
#   'Years active': 15,
#   'No_of_publication': 60},
#  'ADINA LUICAN-MAYER': {'university': 'University of Ottawa',
#   'total_citation': 4660,
#   'hindex': 17,
#   'Years active': 15,
#   'No_of_publication': 73},
#  'Andrew Leifer': {'university': 'Assistant Professor, Department of Physics and Princeton Neuroscience Institute, Princeton',
#   'total_citation': 1813,
#   'hindex': 14,
#   'Years active': 15,
#   'No_of_publication': 22}}

# %%
len(google_dict.keys())
# Out:
# 68

# %%
len(ret_data.keys())
# Out:
# 68

# %%
gs_data = pd.DataFrame(ret_data).T

# %%
# Out:
#                                                                 university  \
# DANIEL J. BENNETT                                    Medical Student, UCSF
# Easton R. White                                University of New Hampshire
# Eric Stabb                               University of Illinois at Chicago
# JENNIFER M. BHATNAGAR    Assistant Professor of Microbial Ecology, Bost...
# John J. Ewel             Professor of Biology (emeritus), University of...
# ...                                                                    ...
# Jeanne Marie VanBriesen  Department of Civil and Environmental Engineer...
# Manjusri Misra           Professor and Tier 1 Canada Research Chair in ...
# Ben Webster              Associate Professor of Mathematics, University...
# ADINA LUICAN-MAYER                                    University of Ottawa
# Andrew Leifer            Assistant Professor, Department of Physics and...
#
#                         total_citation hindex Years active No_of_publication
# DANIEL J. BENNETT                   37      3           15                18
# Easton R. White                    709     13           15                40
# Eric Stabb                        5789     37           15                82
# JENNIFER M. BHATNAGAR             3764     25           15                87
# John J. Ewel                     23273     52           15               152
# ...                                ...    ...          ...               ...
# Jeanne Marie VanBriesen           7269     35           15               163
# Manjusri Misra                   37199     88           15               818
# Ben Webster                       1690     23           15                60
# ADINA LUICAN-MAYER                4660     17           15                73
# Andrew Leifer                     1813     14           15                22
#
# [68 rows x 5 columns]

# %%
a["Years active"].unique()
# Out:
# array([15, 14], dtype=object)

# %%
google_dict["Alison Flynn"]
# Out:
# {'container_type': 'Author',
#  'filled': ['basics',
#   'indices',
#   'counts',
#   'coauthors',
#   'publications',
#   'public_access'],
#  'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>,
#  'scholar_id': '4Me4bYcAAAAJ',
#  'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=4Me4bYcAAAAJ',
#  'name': 'Alison B. Flynn',
#  'affiliation': 'University of Ottawa',
#  'email_domain': '@uottawa.ca',
#  'interests': ['Science education research',
#   'chemistry education research',
#   'organic chemistry',
#   'learning-to-learn',
#   'metacognition'],
#  'citedby': 1730,
#  'organization': 5757600927927532557,
#  'homepage': 'http://www.flynnresearchgroup.com/',
#  'citedby5y': 1181,
#  'hindex': 22,
#  'hindex5y': 18,
#  'i10index': 29,
#  'i10index5y': 27,
#  'cites_per_year': {2007: 6,
#   2008: 20,
#   2009: 40,
#   2010: 27,
#   2011: 61,
#   2012: 34,
#   2013: 45,
#   2014: 83,
#   2015: 111,
#   2016: 103,
#   2017: 121,
#   2018: 151,
#   2019: 218,
#   2020: 331,
#   2021: 283,
#   2022: 76},
#  'coauthors': [],
#  'publications': [{'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Stereocontrolled synthesis of tetrasubstituted olefins',
#     'pub_year': '2007'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:d1gkVwhDpl0C',
#    'num_citations': 482,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3006564587243643331',
#    'cites_id': ['3006564587243643331']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Structure and evaluation of flipped chemistry courses: organic & spectroscopy, large and small, first to third year, English and French',
#     'pub_year': '2015'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:IWHjjKOFINEC',
#    'num_citations': 178,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10580804674163788137',
#    'cites_id': ['10580804674163788137']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Structure and evaluation of flipped chemistry courses: organic & spectroscopy, large and small, first to third year, English and French',
#     'pub_year': '2015'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:UebtZRa9Y70C',
#    'num_citations': 178,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10580804674163788137',
#    'cites_id': ['10580804674163788137']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Single-isomer tetrasubstituted olefins from regioselective and stereospecific palladium-catalyzed coupling of β-chloro-α-iodo-α, β-unsaturated esters',
#     'pub_year': '2006'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:YsMSGLbcyi4C',
#    'num_citations': 121,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16304829272188472534',
#    'cites_id': ['16304829272188472534']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Mechanisms before reactions: A mechanistic approach to the organic chemistry curriculum based on patterns of electron flow',
#     'pub_year': '2015'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:hqOjcs7Dif8C',
#    'num_citations': 88,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11566315633556871240',
#    'cites_id': ['11566315633556871240']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'The development and implementation of a problem-based learning format in a fourth-year undergraduate synthetic organic and medicinal chemistry laboratory course',
#     'pub_year': '2012'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:u5HHmVD_uO8C',
#    'num_citations': 83,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16908549639336839616',
#    'cites_id': ['16908549639336839616']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Students’ interpretations of mechanistic language in organic chemistry before learning reactions',
#     'pub_year': '2017'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:kNdYIx-mwKoC',
#    'num_citations': 53,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12954117563477298929',
#    'cites_id': ['12954117563477298929']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Single-isomer iodochlorination of alkynes and chlorination of alkenes using tetrabutylammonium iodide and dichloroethane',
#     'pub_year': '2007'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:2osOgNQ5qMEC',
#    'num_citations': 50,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=16437959335138243875',
#    'cites_id': ['16437959335138243875']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': "Language of mechanisms: exam analysis reveals students' strengths, strategies, and errors when using the electron-pushing formalism (curved arrows) in new reactions",
#     'pub_year': '2017'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:3fE2CSJIrl8C',
#    'num_citations': 48,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7440997525680251350',
#    'cites_id': ['7440997525680251350']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Developing problem-solving skills through retrosynthetic analysis and clickers in organic chemistry',
#     'pub_year': '2011'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:u-x6o8ySG0sC',
#    'num_citations': 48,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=15351215790325557641',
#    'cites_id': ['15351215790325557641']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Strategies of successful synthesis solutions: Mapping, mechanisms, and more',
#     'pub_year': '2016'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:8k81kl-MbHgC',
#    'num_citations': 43,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4477660638067740717',
#    'cites_id': ['4477660638067740717']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Getting past the rules and to the WHY: Causal mechanistic arguments when judging the plausibility of organic reaction mechanisms',
#     'pub_year': '2019'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:dhFuZR0502QC',
#    'num_citations': 41,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=14777591229820020947',
#    'cites_id': ['14777591229820020947']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'How are students solving familiar and unfamiliar organic chemistry mechanism questions in a new curriculum?',
#     'pub_year': '2018'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:mVmsd5A6BfQC',
#    'num_citations': 40,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=14972022225671838638',
#    'cites_id': ['14972022225671838638']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Acid–base learning outcomes for students in an introductory organic chemistry course',
#     'pub_year': '2015'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:Se3iqnhoufwC',
#    'num_citations': 38,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9679816383394652593',
#    'cites_id': ['9679816383394652593']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'How do students work through organic synthesis learning activities?',
#     'pub_year': '2014'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:qUcmZB5y_30C',
#    'num_citations': 36,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=12847566375231143892',
#    'cites_id': ['12847566375231143892']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Development of an online, postclass question method and its integration with teaching strategies',
#     'pub_year': '2012'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:WF5omc3nYNoC',
#    'num_citations': 33,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7260077657025740950',
#    'cites_id': ['7260077657025740950']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Single-Isomer Trisubstituted Olefins from a Novel Reaction of (E)-β-Chloro-α-iodo-α,β-unsaturated Esters and Amides',
#     'pub_year': '2008'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:qjMakFHDy7sC',
#    'num_citations': 33,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13569542855751143724',
#    'cites_id': ['13569542855751143724']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Patterns of reactions: a card sort task to investigate students’ organization of organic chemistry reactions',
#     'pub_year': '2019'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:9ZlFYXVOiuMC',
#    'num_citations': 30,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5420094771703341958',
#    'cites_id': ['5420094771703341958']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'A simple method to prepare single isomer tetrasubstituted olefins by successive Suzuki–Miyaura cross-couplings of E-β-chloro-α-iodo-α, β-unsaturated esters',
#     'pub_year': '2008'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:9yKSN-GCB0IC',
#    'num_citations': 29,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=18029305331144557167',
#    'cites_id': ['18029305331144557167']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Systems thinking in chemistry education: Theoretical challenges and opportunities',
#     'pub_year': '2019'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:hFOr9nPyWt4C',
#    'num_citations': 28,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7831256064782437239',
#    'cites_id': ['7831256064782437239']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Future directions for systems thinking in chemistry education: Putting the pieces together',
#     'pub_year': '2019'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:-f6ydRqryjwC',
#    'num_citations': 27,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=3819001036144893082',
#    'cites_id': ['3819001036144893082']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'A comparison of how undergraduates, graduate students, and professors organize organic chemistry reactions',
#     'pub_year': '2018'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:Zph67rFs4hoC',
#    'num_citations': 23,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5370832859758401831',
#    'cites_id': ['5370832859758401831']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'NMR Interpretation: Getting from Spectrum to Structure',
#     'pub_year': '2012'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:_FxGoFyzp5QC',
#    'num_citations': 22,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=4797230315825871234',
#    'cites_id': ['4797230315825871234']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Chemical Information Literacy: pKa Values\ue5f8Where Do Students Go Wrong?',
#     'pub_year': '2016'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:5nxA0vEk-isC',
#    'num_citations': 18,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=2999711458581839421',
#    'cites_id': ['2999711458581839421']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Nomenclature101. com: A free, student-driven organic chemistry nomenclature learning tool',
#     'pub_year': '2014'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:roLk4NBRz8UC',
#    'num_citations': 17,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9816629141747801796',
#    'cites_id': ['9816629141747801796']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Essential learning outcomes for delocalization (resonance) concepts: How are they taught, practiced, and assessed in organic chemistry?',
#     'pub_year': '2020'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:_Qo2XoVZTnwC',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=6595508662820832996',
#    'cites_id': ['6595508662820832996'],
#    'public_access': False},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Working with mental models to learn and visualize a new reaction mechanism',
#     'pub_year': '2019'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:QIV2ME_5wuYC',
#    'num_citations': 16,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=13468194151879437221',
#    'cites_id': ['13468194151879437221']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': "What Are Students' Learning and Experiences in an Online Learning Tool Designed for Cognitive and Metacognitive Skill Development?.",
#     'pub_year': '2018'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:4DMP91E08xMC',
#    'num_citations': 14,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8811665039913788762',
#    'cites_id': ['8811665039913788762']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Single isomer trisubstituted olefins bearing alkyl groups',
#     'pub_year': '2010'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:UeHWp8X0CEIC',
#    'num_citations': 12,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=5123883337330019120',
#    'cites_id': ['5123883337330019120']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': "Evaluating students' learning gains and experiences from using nomenclature101. com",
#     'pub_year': '2016'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:MXK_kJrjxJIC',
#    'num_citations': 11,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=11574290473611364861',
#    'cites_id': ['11574290473611364861']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Flipped chemistry courses: Structure, aligning learning outcomes, and evaluation',
#     'pub_year': '2017'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:L8Ckcad2t8MC',
#    'num_citations': 9,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7572226379296465953',
#    'cites_id': ['7572226379296465953']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': "Evaluating students’ learning gains, strategies, and errors using OrgChem101's module: organic mechanisms—mastering the arrows",
#     'pub_year': '2020'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:e5wmG9Sq2KIC',
#    'num_citations': 8,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10624331495823234759',
#    'cites_id': ['10624331495823234759'],
#    'public_access': False},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Building mental models of a reaction mechanism: the influence of static and animated representations, prior knowledge, and spatial ability',
#     'pub_year': '2020'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:HDshCWvjkbEC',
#    'num_citations': 8,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=2849736926475529871',
#    'cites_id': ['2849736926475529871']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Is learning scale-free? Chemistry learning increases EEG fractal power and changes the power law exponent',
#     'pub_year': '2020'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:mB3voiENLucC',
#    'num_citations': 6,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=10696922637353896160',
#    'cites_id': ['10696922637353896160']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Remote teaching: a practical guide with tools, tips, and techniques',
#     'pub_year': '2020'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:O3NaXMp0MMsC',
#    'num_citations': 5,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=15964065725321331018',
#    'cites_id': ['15964065725321331018']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': "What works? What's missing? An evaluation model for science curricula that analyses learning outcomes through five lenses",
#     'pub_year': '2020'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:TFP_iSt0sucC',
#    'num_citations': 5,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=998736152236081607',
#    'cites_id': ['998736152236081607']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Reasoning, granularity, and comparisons in students’ arguments on two organic chemistry items',
#     'pub_year': '2021'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:35N4QoGY0k4C',
#    'num_citations': 4,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=9645701510180345076',
#    'cites_id': ['9645701510180345076'],
#    'public_access': True},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Ten essential delocalization learning outcomes: How well are they achieved?',
#     'pub_year': '2021'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:lSLTfruPkqcC',
#    'num_citations': 2,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=6138004294307211134',
#    'cites_id': ['6138004294307211134']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': "An online categorization task to investigate changes in students' interpretations of organic chemistry reactions",
#     'pub_year': '2020'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:ZeXyd9-uunAC',
#    'num_citations': 2,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=8796197191026255645',
#    'cites_id': ['8796197191026255645']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Response process validity evidence in chemistry education research',
#     'pub_year': '2021'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:2P1L_qKh6hAC',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=14327745493448331279',
#    'cites_id': ['14327745493448331279']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Engaging students as co-creators of course resources and learning experiences',
#     'pub_year': '2021'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:g5m5HwL7SMYC',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=1903517073067930640',
#    'cites_id': ['1903517073067930640']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': '27. A Post-Class Question Strategy That Provides Feedback and Connects In-and Out-of-Class Learning',
#     'pub_year': '2012'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:ufrVoPGSRksC',
#    'num_citations': 1,
#    'citedby_url': 'https://scholar.google.com/scholar?oi=bibs&hl=en&cites=7220781617640736934',
#    'cites_id': ['7220781617640736934']},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Investigating educators’ perspectives towards systems thinking in chemistry education from international contexts',
#     'pub_year': '2022'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:ZHo1McVdvXMC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'The role of language in students’ justifications of scientific phenomena',
#     'pub_year': '2022'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:HoB7MX3m0LUC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Investigating the role of multiple categorization tasks in a curriculum designed around mechanistic patterns and principles',
#     'pub_year': '2022'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:SeFeTyx0c_EC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'HOW DO OUR PROGRAMS AND COURSES NEED TO CHANGE TO BETTER INCLUDE, EQUIP, AND EMPOWER LEARNERS?',
#     'pub_year': '2021'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:pqnbT2bcN3wC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'The evaluation of an integrated Growth & Goals Module to better equip students with learning skills in postsecondary courses: systematic, scalable, and explicit',
#     'pub_year': '2021'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:vV6vV6tmYwMC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Scaffolding Synthesis Skills in Organic Chemistry',
#     'pub_year': '2021'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:70eg2SAEIzsC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Reasoning, granularity, and comparisons: a unit-based method for characterizing students’ arguments on chemistry assessments',
#     'pub_year': '2021'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:RYcK_YlVTxYC',
#    'num_citations': 0,
#    'public_access': True},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Introduction to the special issue dedicated to Dr. Margaret-Ann Armour',
#     'pub_year': '2021'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:ldfaerwXgEUC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Les groupes de discussion (DGDs)| Tutoriels',
#     'pub_year': '2020'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:NaGl4SEjCO4C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Enseignement à distance: un guide pour les assistantes et assistants d’enseignement',
#     'pub_year': '2020'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:ns9cj8rnVeAC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Creating and sharing content (eg, videos)',
#     'pub_year': '2020'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:J_g5lzvAfSwC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Specific examples of video set-ups', 'pub_year': '2020'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:hMod-77fHWUC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Remote Teaching: A Guide for Teaching Assistants',
#     'pub_year': '2020'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:RGFaLdJalmkC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Croissance et objectifs: version indépendante',
#     'pub_year': '2020'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:GnPB-g6toBAC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Enseignement à distance: un guide pratique avec des outils, techniques, et suggestions',
#     'pub_year': '2020'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:BqipwSGYUEgC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Growth and Goals: Independent', 'pub_year': '2020'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:NMxIlDl6LWMC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Characterizing students\' abilities to reason about" why" on organic chemistry assessments',
#     'pub_year': '2019'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:iH-uZ7U-co4C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Growth & Goals: Course', 'pub_year': '2019'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:YFjsv_pBGBYC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Chemistry Education Research in the Canadian Journal of Chemistry: expanded scope and guidelines for authors',
#     'pub_year': '2019'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:hC7cP41nSMkC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Croissance et objectifs: cours', 'pub_year': '2018'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:blknAaTinKkC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Exploring learning outcomes when using multimedia for chemistry reaction mechanisms',
#     'pub_year': '2017'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:4TOpqqG69KYC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'OrgChem101. com: Online learning modules that can be used in blended, flipped, traditional, or other classroom environments',
#     'pub_year': '2017'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:_kc_bZDykSQC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Teaching for success in solving organic synthesis problems',
#     'pub_year': '2017'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:YOwf2qJgpHMC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': "Patterns of reactions: A card sort task to explore students' connections across organic chemistry reactions",
#     'pub_year': '2017'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:ULOm3_A8WrAC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Symbolism before reactions: What is the effect of a stepwise approach to the mechanistic organic chemistry curriculum?',
#     'pub_year': '2016'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:qxL8FJ1GzNcC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Flipped & blended organic chemistry and spectroscopy courses: Structure and evaluation',
#     'pub_year': '2016'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:M3ejUd6NZC8C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Effective strategies for solving synthesis-type problems in organic chemistry',
#     'pub_year': '2014'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:R3hNpaxXUhUC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'http://bjp. rcpsych. org'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:JV2RwH3_ST0C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Systems Thinking in Chemistry Education—STICE Project'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:k_IJM867U9cC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Chemistry Education Research and Practice'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:j3f4tGmQtD8C',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Chemistry Education Research and Practice c9rp00198k'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:TQgYirikUcIC',
#    'num_citations': 0},
#   {'container_type': 'Publication',
#    'source': <PublicationSource.AUTHOR_PUBLICATION_ENTRY: 'AUTHOR_PUBLICATION_ENTRY'>,
#    'bib': {'title': 'Chemistry Education Research and Practice'},
#    'filled': False,
#    'author_pub_id': '4Me4bYcAAAAJ:Wp0gIr-vW9MC',
#    'num_citations': 0}],
#  'public_access': {'available': 2, 'not_available': 2}}

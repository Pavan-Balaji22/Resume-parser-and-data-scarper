# %%
from scholarly import scholarly as sc

# %%
a=sc.search_author("Diana inkpen")

# %%
print(sc.fill(next(a)))
# Out:
# {'container_type': 'Author', 'filled': ['basics', 'indices', 'counts', 'coauthors', 'publications', 'public_access'], 'source': <AuthorSource.SEARCH_AUTHOR_SNIPPETS: 'SEARCH_AUTHOR_SNIPPETS'>, 'scholar_id': '66pwIBcAAAAJ', 'url_picture': 'https://scholar.google.com/citations?view_op=medium_photo&user=66pwIBcAAAAJ', 'name': 'Diana Inkpen', 'affiliation': 'University of Ottawa (Computer Science)', 'email_domain': '@site.uottawa.ca', 'interests': ['Natural Language Processing', 'Computational Linguistics', 'Information Retrieval'], 'citedby': 7645, 'organization': 5757600927927532557, 'citedby5y': 4591, 'hindex': 39, 'hindex5y': 30, 'i10index': 109, 'i10index5y': 70, 'cites_per_year': {2006: 41, 2007: 74, 2008: 82, 2009: 139, 2010: 216, 2011: 277, 2012: 313, 2013: 348, 2014: 436, 2015: 462, 2016: 532, 2017: 556, 2018: 687, 2019: 978, 2020: 1048, 2021: 1053, 2022: 258}, 'coauthors': [{'container_type': 'Author', 'filled': [], 'scholar_id': 'GZWObWoAAAAJ', 'source': <AuthorSource.CO_AUTHO
# ...
